# %%
from image_products import *
from webcoos_request import *

# %%
start_time = '2024-07-22 00:00:00'
end_time = '2024-07-23 00:00:00'
station_names = ['oakisland_west', 'jennette_north','currituck_hampton_inn']
inv = get_inventory(start_time=start_time, end_time=end_time,station=station_names[0])  # set station_names from list to the same object in both IP and get_inventory function
print(inv[0]['data']['properties']['url'])
# Out:
# Readable date: Monday, July 22, 2024, 00:00:00
# Readable date: Tuesday, July 23, 2024, 00:00:00
# Request params: {'service': 'oakisland_west-video-archive-s3', 'starting_after': '2024-07-22T00:00:00', 'starting_before': '2024-07-23T00:00:00'}
# https://s3.us-west-2.amazonaws.com/webcoos/media/sources/webcoos/groups/uncw/assets/oakisland_west/feeds/raw-video-data/products/video-archive/elements/2024/07/22/oakisland_west-2024-07-22-000021Z.mp4

# %%
url = inv[0]['data']['properties']['url']
IP = ImageProcessor(stationName=station_names[0]) # set station_names from list to the same object in both IP and get_inventory function
# Out:
# Attempting to create directory: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\images
# Directory already exists: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\images
# Attempting to create directory: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\images\oakisland_west
# Directory already exists: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\images\oakisland_west
# Attempting to create directory: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\images\oakisland_west\timex
# Directory already exists: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\images\oakisland_west\timex
# Attempting to create directory: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\images\oakisland_west\bright
# Directory already exists: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\images\oakisland_west\bright
# Attempting to create directory: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\images\oakisland_west\average
# Directory already exists: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\images\oakisland_west\average

# %%
IP.download_video(url)
# Out:
# Video download complete. Duration: 4.91 seconds.

# %%
IP.generate_timex_image()
IP.generate_brightest_pixel_image()
IP.generate_timexavg_shoreline()
# Out:
# Station path: .\configs\oakisland_west.config.json
# Station path: .\configs\oakisland_west.config.json
# Directory exists: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\transect_jsons\oakisland_west
# Saved JSON to: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\transect_jsons\oakisland_west\oakisland_west-2024-07-22_0000.avg.slVars.json
# Photo dimensions: (460, 614, 3)
# Shoreline coordinates (first 10): [[331 163]
#  [327 166]
#  [327 169]
#  [327 172]
#  [327 175]
#  [328 178]
#  [335 181]
#  [338 184]
#  [335 187]
#  [334 190]]
# Directory exists: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\images\oakisland_west\average
# Saved fig_tranSL to: c:\Users\Corey Dearing\Desktop\ShorelineProjectRepo\images\oakisland_west\average\oakisland_west-2024-07-22_0000.tranSL-avg.fix.jpeg
# (array([[331, 163],
#         [327, 166],
#         [327, 169],
#         [327, 172],
#         [327, 175],
#         [328, 178],
#         [335, 181],
#         [338, 184],
#         [335, 187],
#         [334, 190],
#         [335, 193],
#         [328, 196],
#         [323, 199],
#         [319, 202],
#         [316, 205],
#         [308, 208],
#         [305, 211],
#         [302, 214],
#         [297, 217],
#         [297, 220],
#         [290, 223],
#         [277, 226],
#         [267, 229],
#         [279, 232]]),
#  <Figure size 640x480 with 1 Axes>)

# %%
IP.clean_up()
# Out:
# Deleted temporary video file: oakisland_west-2024-07-22-000021Z.mp4

# %%
IP.plot_image_process()
